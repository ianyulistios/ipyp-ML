# %%
import numpy as np
import sklearn as sk
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataRaw = pd.read_csv('mushrooms.csv')
data = dataRaw.drop(columns=['cap-surface','gill-attachment','stalk-root','veil-type','veil-color'], axis=1)
data
# Out:
#      class cap-shape cap-color bruises odor gill-spacing gill-size gill-color  \
# 0        p         x         n       t    p            c         n          k
# 1        e         x         y       t    a            c         b          k
# 2        e         b         w       t    l            c         b          n
# 3        p         x         w       t    p            c         n          n
# 4        e         x         g       f    n            w         b          k
# 5        e         x         y       t    a            c         b          n
# 6        e         b         w       t    a            c         b          g
# 7        e         b         w       t    l            c         b          n
# 8        p         x         w       t    p            c         n          p
# 9        e         b         y       t    a            c         b          g
# 10       e         x         y       t    l            c         b          g
# 11       e         x         y       t    a            c         b          n
# 12       e         b         y       t    a            c         b          w
# 13       p         x         w       t    p            c         n          k
# 14       e         x         n       f    n            w         b          n
# 15       e         s         g       f    n            c         n          k
# 16       e         f         w       f    n            w         b          k
# 17       p         x         n       t    p            c         n          n
# 18       p         x         w       t    p            c         n          n
# 19       p         x         n       t    p            c         n          k
# 20       e         b         y       t    a            c         b          k
# 21       p         x         n       t    p            c         n          n
# 22       e         b         y       t    l            c         b          k
# 23       e         b         w       t    a            c         b          w
# 24       e         b         w       t    l            c         b          g
# 25       p         f         w       t    p            c         n          n
# 26       e         x         y       t    a            c         b          n
# 27       e         x         w       t    l            c         b          w
# 28       e         f         n       f    n            c         n          k
# 29       e         x         y       t    a            w         n          n
# ...    ...       ...       ...     ...  ...          ...       ...        ...
# 8094     e         b         g       f    n            w         b          g
# 8095     p         x         c       f    m            c         b          y
# 8096     e         k         w       f    n            w         b          w
# 8097     p         k         n       f    s            c         n          b
# 8098     p         k         e       f    y            c         n          b
# 8099     e         k         w       f    n            w         b          w
# 8100     e         f         n       f    n            c         b          o
# 8101     p         k         e       f    s            c         n          b
# 8102     e         x         n       f    n            c         b          y
# 8103     e         k         n       f    n            c         b          y
# 8104     e         k         n       f    n            c         b          y
# 8105     e         k         n       f    n            c         b          y
# 8106     e         k         n       f    n            c         b          o
# 8107     e         x         n       f    n            c         b          y
# 8108     p         k         e       f    y            c         n          b
# 8109     e         b         w       f    n            w         b          w
# 8110     e         x         n       f    n            c         b          o
# 8111     e         k         w       f    n            w         b          p
# 8112     e         k         n       f    n            c         b          o
# 8113     p         k         e       f    y            c         n          b
# 8114     p         f         c       f    m            c         b          y
# 8115     e         x         n       f    n            c         b          y
# 8116     p         k         n       f    s            c         n          b
# 8117     p         k         e       f    y            c         n          b
# 8118     p         k         n       f    f            c         n          b
# 8119     e         k         n       f    n            c         b          y
# 8120     e         x         n       f    n            c         b          y
# 8121     e         f         n       f    n            c         b          n
# 8122     p         k         n       f    y            c         n          b
# 8123     e         x         n       f    n            c         b          y
#
#      stalk-shape stalk-surface-above-ring stalk-surface-below-ring  \
# 0              e                        s                        s
# 1              e                        s                        s
# 2              e                        s                        s
# 3              e                        s                        s
# 4              t                        s                        s
# 5              e                        s                        s
# 6              e                        s                        s
# 7              e                        s                        s
# 8              e                        s                        s
# 9              e                        s                        s
# 10             e                        s                        s
# 11             e                        s                        s
# 12             e                        s                        s
# 13             e                        s                        s
# 14             t                        s                        f
# 15             e                        s                        s
# 16             t                        s                        s
# 17             e                        s                        s
# 18             e                        s                        s
# 19             e                        s                        s
# 20             e                        s                        s
# 21             e                        s                        s
# 22             e                        s                        s
# 23             e                        s                        s
# 24             e                        s                        s
# 25             e                        s                        s
# 26             e                        s                        s
# 27             e                        s                        s
# 28             e                        s                        s
# 29             t                        s                        s
# ...          ...                      ...                      ...
# 8094           e                        k                        s
# 8095           e                        k                        y
# 8096           e                        k                        s
# 8097           t                        k                        k
# 8098           t                        k                        k
# 8099           e                        k                        k
# 8100           e                        s                        s
# 8101           t                        s                        s
# 8102           e                        s                        s
# 8103           e                        s                        s
# 8104           e                        s                        s
# 8105           e                        s                        s
# 8106           e                        s                        s
# 8107           e                        s                        s
# 8108           t                        k                        s
# 8109           e                        s                        s
# 8110           e                        s                        s
# 8111           e                        s                        s
# 8112           e                        s                        s
# 8113           t                        k                        k
# 8114           e                        k                        y
# 8115           e                        s                        s
# 8116           t                        s                        k
# 8117           t                        k                        s
# 8118           t                        k                        s
# 8119           e                        s                        s
# 8120           e                        s                        s
# 8121           e                        s                        s
# 8122           t                        s                        k
# 8123           e                        s                        s
#
#      stalk-color-above-ring stalk-color-below-ring ring-number ring-type  \
# 0                         w                      w           o         p
# 1                         w                      w           o         p
# 2                         w                      w           o         p
# 3                         w                      w           o         p
# 4                         w                      w           o         e
# 5                         w                      w           o         p
# 6                         w                      w           o         p
# 7                         w                      w           o         p
# 8                         w                      w           o         p
# 9                         w                      w           o         p
# 10                        w                      w           o         p
# 11                        w                      w           o         p
# 12                        w                      w           o         p
# 13                        w                      w           o         p
# 14                        w                      w           o         e
# 15                        w                      w           o         p
# 16                        w                      w           o         e
# 17                        w                      w           o         p
# 18                        w                      w           o         p
# 19                        w                      w           o         p
# 20                        w                      w           o         p
# 21                        w                      w           o         p
# 22                        w                      w           o         p
# 23                        w                      w           o         p
# 24                        w                      w           o         p
# 25                        w                      w           o         p
# 26                        w                      w           o         p
# 27                        w                      w           o         p
# 28                        w                      w           o         p
# 29                        w                      w           o         p
# ...                     ...                    ...         ...       ...
# 8094                      w                      w           t         p
# 8095                      c                      c           n         n
# 8096                      w                      w           t         p
# 8097                      p                      p           o         e
# 8098                      w                      p           o         e
# 8099                      w                      w           t         p
# 8100                      o                      o           o         p
# 8101                      p                      w           o         e
# 8102                      o                      o           o         p
# 8103                      o                      o           o         p
# 8104                      o                      o           o         p
# 8105                      o                      o           o         p
# 8106                      o                      o           o         p
# 8107                      o                      o           o         p
# 8108                      p                      w           o         e
# 8109                      w                      w           t         p
# 8110                      o                      o           o         p
# 8111                      w                      w           t         p
# 8112                      o                      o           o         p
# 8113                      p                      p           o         e
# 8114                      c                      c           n         n
# 8115                      o                      o           o         p
# 8116                      p                      w           o         e
# 8117                      p                      w           o         e
# 8118                      p                      w           o         e
# 8119                      o                      o           o         p
# 8120                      o                      o           o         p
# 8121                      o                      o           o         p
# 8122                      w                      w           o         e
# 8123                      o                      o           o         p
#
#      spore-print-color population habitat
# 0                    k          s       u
# 1                    n          n       g
# 2                    n          n       m
# 3                    k          s       u
# 4                    n          a       g
# 5                    k          n       g
# 6                    k          n       m
# 7                    n          s       m
# 8                    k          v       g
# 9                    k          s       m
# 10                   n          n       g
# 11                   k          s       m
# 12                   n          s       g
# 13                   n          v       u
# 14                   k          a       g
# 15                   n          y       u
# 16                   n          a       g
# 17                   k          s       g
# 18                   n          s       u
# 19                   n          s       u
# 20                   n          s       m
# 21                   n          v       g
# 22                   n          s       m
# 23                   n          n       m
# 24                   k          s       m
# 25                   n          v       g
# 26                   n          n       m
# 27                   n          n       m
# 28                   k          y       u
# 29                   n          v       d
# ...                ...        ...     ...
# 8094                 w          n       g
# 8095                 w          c       d
# 8096                 w          n       g
# 8097                 w          v       l
# 8098                 w          v       d
# 8099                 w          s       g
# 8100                 b          v       l
# 8101                 w          v       p
# 8102                 n          c       l
# 8103                 o          c       l
# 8104                 n          v       l
# 8105                 y          v       l
# 8106                 n          v       l
# 8107                 n          c       l
# 8108                 w          v       l
# 8109                 w          n       g
# 8110                 n          v       l
# 8111                 w          n       g
# 8112                 b          v       l
# 8113                 w          v       d
# 8114                 w          c       d
# 8115                 o          v       l
# 8116                 w          v       l
# 8117                 w          v       d
# 8118                 w          v       d
# 8119                 b          c       l
# 8120                 b          v       l
# 8121                 b          c       l
# 8122                 w          v       l
# 8123                 o          c       l
#
# [8124 rows x 18 columns]

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

for feature in data.columns:
    print(feature, ':', data[feature].unique())
# Out:
# class : ['p' 'e']
# cap-shape : ['x' 'b' 's' 'f' 'k' 'c']
# cap-color : ['n' 'y' 'w' 'g' 'e' 'p' 'b' 'u' 'c' 'r']
# bruises : ['t' 'f']
# odor : ['p' 'a' 'l' 'n' 'f' 'c' 'y' 's' 'm']
# gill-spacing : ['c' 'w']
# gill-size : ['n' 'b']
# gill-color : ['k' 'n' 'g' 'p' 'w' 'h' 'u' 'e' 'b' 'r' 'y' 'o']
# stalk-shape : ['e' 't']
# stalk-surface-above-ring : ['s' 'f' 'k' 'y']
# stalk-surface-below-ring : ['s' 'f' 'y' 'k']
# stalk-color-above-ring : ['w' 'g' 'p' 'n' 'b' 'e' 'o' 'c' 'y']
# stalk-color-below-ring : ['w' 'p' 'g' 'b' 'n' 'e' 'y' 'o' 'c']
# ring-number : ['o' 't' 'n']
# ring-type : ['p' 'e' 'l' 'f' 'n']
# spore-print-color : ['k' 'n' 'u' 'h' 'w' 'r' 'o' 'y' 'b']
# population : ['s' 'n' 'a' 'v' 'y' 'c']
# habitat : ['u' 'g' 'm' 'd' 'p' 'w' 'l']

# %%
lab_enc = preprocessing.LabelEncoder()

Y = data['class'].values
Y_encode = lab_enc.fit_transform(Y)
Y_inverse = lab_enc.inverse_transform(Y_encode)

for feature in data.columns[1:]:
    data[feature] = lab_enc.fit_transform(data[feature])
    
X = data.drop(columns='class', axis=1).values

print(X)
print(Y_encode)
# Out:
# [[5 4 1 ..., 2 3 5]
#  [5 9 1 ..., 3 2 1]
#  [0 8 1 ..., 3 2 3]
#  ...,
#  [2 4 0 ..., 0 1 2]
#  [3 4 0 ..., 7 4 2]
#  [5 4 0 ..., 4 1 2]]
# [1 0 0 ..., 0 1 0]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y_encode, test_size=0.2, random_state=1)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=12, algorithm='auto')
knn.fit(X_train,y_train)

print('Training Score: %.2f%%' % (knn.score(X_train, y_train) * 100))
print('Test Score: %.2f%%' % (knn.score(X_test, y_test) * 100))
# Out:
# Training Score: 99.43%
# Test Score: 99.02%

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=500, n_jobs=-1)
rfc.fit(X_train, y_train)
print('Training Score: %.2f%%' % (rfc.score(X_train, y_train) * 100))
print('Test Score: %.2f%%' % (rfc.score(X_test, y_test) * 100))
# Out:
# Training Score: 100.00%
# Test Score: 100.00%

# %%
importances = rfc.feature_importances_
features = data.columns[1:]
sort_indices = np.argsort(importances)[::-1]
sorted_features = []
for idx in sort_indices:
    sorted_features.append(features[idx])
plt.bar(range(len(importances)), importances[sort_indices], align='center');
plt.xticks(range(len(importances)), sorted_features, rotation='vertical');
plt.xlim([-1, len(importances)])
plt.grid(False)
plt.show()

# %%
top4 = sorted_features[:4]
topX = data[top4].values
print(top4)
print(topX)
print(Y_encode)

X_train, X_test, y_train, y_test = train_test_split(topX, Y_encode, test_size=0.2, random_state=1)
# Out:
# ['odor', 'gill-color', 'gill-size', 'spore-print-color']
# [[ 6  4  1  2]
#  [ 0  4  0  3]
#  [ 3  5  0  3]
#  ...,
#  [ 5  5  0  0]
#  [ 8  0  1  7]
#  [ 5 11  0  4]]
# [1 0 0 ..., 0 1 0]

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=500, n_jobs=2)
rfc.fit(X_train, y_train)
print('Training Score: %.2f%%' % (rfc.score(X_train, y_train) * 100))
print('Test Score: %.2f%%' % (rfc.score(X_test, y_test) * 100))
# Out:
# Training Score: 99.54%
# Test Score: 99.14%

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=20, algorithm='auto')
knn.fit(X_train,y_train)

print('Training Score: %.2f%%' % (knn.score(X_train, y_train) * 100))
print('Test Score: %.2f%%' % (knn.score(X_test, y_test) * 100))
# Out:
# Training Score: 99.37%
# Test Score: 99.08%

# %%
data
# Out:
#      class  cap-shape  cap-color  bruises  odor  gill-spacing  gill-size  \
# 0        p          5          4        1     6             0          1
# 1        e          5          9        1     0             0          0
# 2        e          0          8        1     3             0          0
# 3        p          5          8        1     6             0          1
# 4        e          5          3        0     5             1          0
# 5        e          5          9        1     0             0          0
# 6        e          0          8        1     0             0          0
# 7        e          0          8        1     3             0          0
# 8        p          5          8        1     6             0          1
# 9        e          0          9        1     0             0          0
# 10       e          5          9        1     3             0          0
# 11       e          5          9        1     0             0          0
# 12       e          0          9        1     0             0          0
# 13       p          5          8        1     6             0          1
# 14       e          5          4        0     5             1          0
# 15       e          4          3        0     5             0          1
# 16       e          2          8        0     5             1          0
# 17       p          5          4        1     6             0          1
# 18       p          5          8        1     6             0          1
# 19       p          5          4        1     6             0          1
# 20       e          0          9        1     0             0          0
# 21       p          5          4        1     6             0          1
# 22       e          0          9        1     3             0          0
# 23       e          0          8        1     0             0          0
# 24       e          0          8        1     3             0          0
# 25       p          2          8        1     6             0          1
# 26       e          5          9        1     0             0          0
# 27       e          5          8        1     3             0          0
# 28       e          2          4        0     5             0          1
# 29       e          5          9        1     0             1          1
# ...    ...        ...        ...      ...   ...           ...        ...
# 8094     e          0          3        0     5             1          0
# 8095     p          5          1        0     4             0          0
# 8096     e          3          8        0     5             1          0
# 8097     p          3          4        0     7             0          1
# 8098     p          3          2        0     8             0          1
# 8099     e          3          8        0     5             1          0
# 8100     e          2          4        0     5             0          0
# 8101     p          3          2        0     7             0          1
# 8102     e          5          4        0     5             0          0
# 8103     e          3          4        0     5             0          0
# 8104     e          3          4        0     5             0          0
# 8105     e          3          4        0     5             0          0
# 8106     e          3          4        0     5             0          0
# 8107     e          5          4        0     5             0          0
# 8108     p          3          2        0     8             0          1
# 8109     e          0          8        0     5             1          0
# 8110     e          5          4        0     5             0          0
# 8111     e          3          8        0     5             1          0
# 8112     e          3          4        0     5             0          0
# 8113     p          3          2        0     8             0          1
# 8114     p          2          1        0     4             0          0
# 8115     e          5          4        0     5             0          0
# 8116     p          3          4        0     7             0          1
# 8117     p          3          2        0     8             0          1
# 8118     p          3          4        0     2             0          1
# 8119     e          3          4        0     5             0          0
# 8120     e          5          4        0     5             0          0
# 8121     e          2          4        0     5             0          0
# 8122     p          3          4        0     8             0          1
# 8123     e          5          4        0     5             0          0
#
#       gill-color  stalk-shape  stalk-surface-above-ring  \
# 0              4            0                         2
# 1              4            0                         2
# 2              5            0                         2
# 3              5            0                         2
# 4              4            1                         2
# 5              5            0                         2
# 6              2            0                         2
# 7              5            0                         2
# 8              7            0                         2
# 9              2            0                         2
# 10             2            0                         2
# 11             5            0                         2
# 12            10            0                         2
# 13             4            0                         2
# 14             5            1                         2
# 15             4            0                         2
# 16             4            1                         2
# 17             5            0                         2
# 18             5            0                         2
# 19             4            0                         2
# 20             4            0                         2
# 21             5            0                         2
# 22             4            0                         2
# 23            10            0                         2
# 24             2            0                         2
# 25             5            0                         2
# 26             5            0                         2
# 27            10            0                         2
# 28             4            0                         2
# 29             5            1                         2
# ...          ...          ...                       ...
# 8094           2            0                         1
# 8095          11            0                         1
# 8096          10            0                         1
# 8097           0            1                         1
# 8098           0            1                         1
# 8099          10            0                         1
# 8100           6            0                         2
# 8101           0            1                         2
# 8102          11            0                         2
# 8103          11            0                         2
# 8104          11            0                         2
# 8105          11            0                         2
# 8106           6            0                         2
# 8107          11            0                         2
# 8108           0            1                         1
# 8109          10            0                         2
# 8110           6            0                         2
# 8111           7            0                         2
# 8112           6            0                         2
# 8113           0            1                         1
# 8114          11            0                         1
# 8115          11            0                         2
# 8116           0            1                         2
# 8117           0            1                         1
# 8118           0            1                         1
# 8119          11            0                         2
# 8120          11            0                         2
# 8121           5            0                         2
# 8122           0            1                         2
# 8123          11            0                         2
#
#       stalk-surface-below-ring  stalk-color-above-ring  \
# 0                            2                       7
# 1                            2                       7
# 2                            2                       7
# 3                            2                       7
# 4                            2                       7
# 5                            2                       7
# 6                            2                       7
# 7                            2                       7
# 8                            2                       7
# 9                            2                       7
# 10                           2                       7
# 11                           2                       7
# 12                           2                       7
# 13                           2                       7
# 14                           0                       7
# 15                           2                       7
# 16                           2                       7
# 17                           2                       7
# 18                           2                       7
# 19                           2                       7
# 20                           2                       7
# 21                           2                       7
# 22                           2                       7
# 23                           2                       7
# 24                           2                       7
# 25                           2                       7
# 26                           2                       7
# 27                           2                       7
# 28                           2                       7
# 29                           2                       7
# ...                        ...                     ...
# 8094                         2                       7
# 8095                         3                       1
# 8096                         2                       7
# 8097                         1                       6
# 8098                         1                       7
# 8099                         1                       7
# 8100                         2                       5
# 8101                         2                       6
# 8102                         2                       5
# 8103                         2                       5
# 8104                         2                       5
# 8105                         2                       5
# 8106                         2                       5
# 8107                         2                       5
# 8108                         2                       6
# 8109                         2                       7
# 8110                         2                       5
# 8111                         2                       7
# 8112                         2                       5
# 8113                         1                       6
# 8114                         3                       1
# 8115                         2                       5
# 8116                         1                       6
# 8117                         2                       6
# 8118                         2                       6
# 8119                         2                       5
# 8120                         2                       5
# 8121                         2                       5
# 8122                         1                       7
# 8123                         2                       5
#
#       stalk-color-below-ring  ring-number  ring-type  spore-print-color  \
# 0                          7            1          4                  2
# 1                          7            1          4                  3
# 2                          7            1          4                  3
# 3                          7            1          4                  2
# 4                          7            1          0                  3
# 5                          7            1          4                  2
# 6                          7            1          4                  2
# 7                          7            1          4                  3
# 8                          7            1          4                  2
# 9                          7            1          4                  2
# 10                         7            1          4                  3
# 11                         7            1          4                  2
# 12                         7            1          4                  3
# 13                         7            1          4                  3
# 14                         7            1          0                  2
# 15                         7            1          4                  3
# 16                         7            1          0                  3
# 17                         7            1          4                  2
# 18                         7            1          4                  3
# 19                         7            1          4                  3
# 20                         7            1          4                  3
# 21                         7            1          4                  3
# 22                         7            1          4                  3
# 23                         7            1          4                  3
# 24                         7            1          4                  2
# 25                         7            1          4                  3
# 26                         7            1          4                  3
# 27                         7            1          4                  3
# 28                         7            1          4                  2
# 29                         7            1          4                  3
# ...                      ...          ...        ...                ...
# 8094                       7            2          4                  7
# 8095                       1            0          3                  7
# 8096                       7            2          4                  7
# 8097                       6            1          0                  7
# 8098                       6            1          0                  7
# 8099                       7            2          4                  7
# 8100                       5            1          4                  0
# 8101                       7            1          0                  7
# 8102                       5            1          4                  3
# 8103                       5            1          4                  4
# 8104                       5            1          4                  3
# 8105                       5            1          4                  8
# 8106                       5            1          4                  3
# 8107                       5            1          4                  3
# 8108                       7            1          0                  7
# 8109                       7            2          4                  7
# 8110                       5            1          4                  3
# 8111                       7            2          4                  7
# 8112                       5            1          4                  0
# 8113                       6            1          0                  7
# 8114                       1            0          3                  7
# 8115                       5            1          4                  4
# 8116                       7            1          0                  7
# 8117                       7            1          0                  7
# 8118                       7            1          0                  7
# 8119                       5            1          4                  0
# 8120                       5            1          4                  0
# 8121                       5            1          4                  0
# 8122                       7            1          0                  7
# 8123                       5            1          4                  4
#
#       population  habitat
# 0              3        5
# 1              2        1
# 2              2        3
# 3              3        5
# 4              0        1
# 5              2        1
# 6              2        3
# 7              3        3
# 8              4        1
# 9              3        3
# 10             2        1
# 11             3        3
# 12             3        1
# 13             4        5
# 14             0        1
# 15             5        5
# 16             0        1
# 17             3        1
# 18             3        5
# 19             3        5
# 20             3        3
# 21             4        1
# 22             3        3
# 23             2        3
# 24             3        3
# 25             4        1
# 26             2        3
# 27             2        3
# 28             5        5
# 29             4        0
# ...          ...      ...
# 8094           2        1
# 8095           1        0
# 8096           2        1
# 8097           4        2
# 8098           4        0
# 8099           3        1
# 8100           4        2
# 8101           4        4
# 8102           1        2
# 8103           1        2
# 8104           4        2
# 8105           4        2
# 8106           4        2
# 8107           1        2
# 8108           4        2
# 8109           2        1
# 8110           4        2
# 8111           2        1
# 8112           4        2
# 8113           4        0
# 8114           1        0
# 8115           4        2
# 8116           4        2
# 8117           4        0
# 8118           4        0
# 8119           1        2
# 8120           4        2
# 8121           1        2
# 8122           4        2
# 8123           1        2
#
# [8124 rows x 18 columns]
